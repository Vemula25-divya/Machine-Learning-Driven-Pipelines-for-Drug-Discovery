# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# To see available sheet names
df = pd.read_csv(r"C:\Users\DELL\Downloads\Vitas_PlaF_Screeningdata.csv")

df.info()        # Data types and non-null counts
df.describe()    # Summary stats for numeric columns
df.shape         # (rows, columns)
df.columns       # Column names
df.head(5)        # First few rows

df.columns.to_list()  # List all column names
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 358 entries, 0 to 357
# Columns: 176 entries, Stars to Memb2 z
# dtypes: float64(130), int64(2), object(44)
# memory usage: 492.4+ KB
# ['Stars',
#  'Title',
#  'Entry ID',
#  'Entry Name',
#  'Date Added',
#  'Date Modified',
#  'receptor',
#  'created disulfur',
#  'prepared',
#  'grid version',
#  'Source File Index',
#  'PDB CRYST1 z',
#  'gridbox ligxrange',
#  'gridbox ligyrange',
#  'gridbox ligzrange',
#  'gridbox xcent',
#  'gridbox xrange',
#  'gridbox ycent',
#  'gridbox yrange',
#  'gridbox zcent',
#  'gridbox zrange',
#  'Bend Energy-S-OPLS',
#  'Dihedral Energy-S-OPLS',
#  'El-14 Energy-S-OPLS',
#  'Electrostatic Energy-S-OPLS',
#  'LJ-14 Energy-S-OPLS',
#  'Max Derivative-S-OPLS',
#  'Potential Energy-S-OPLS',
#  'RMS Derivative-S-OPLS',
#  'Stretch Energy-S-OPLS',
#  'Van der Waals Energy-S-OPLS',
#  'target temperature',
#  'PDB CRYST1 a',
#  'PDB CRYST1 alpha',
#  'PDB CRYST1 b',
#  'PDB CRYST1 beta',
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from rdkit import Chem
from rdkit.Chem.Scaffolds import MurckoScaffold
from rdkit.Chem import Draw

smiles_col = 'smiles' if 'smiles' in df.columns else 'Smiles'
df = df.dropna(subset=[smiles_col])

def get_scaffold(smiles):
    try:
        mol = Chem.MolFromSmiles(smiles)
        if mol:
            scaffold = MurckoScaffold.GetScaffoldForMol(mol)
            return Chem.MolToSmiles(scaffold)
    except:
        return None

df['Scaffold_SMILES'] = df[smiles_col].apply(get_scaffold)

scaffold_counts = df['Scaffold_SMILES'].value_counts()
scaffold_counts.head(10)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 7
#       5 from rdkit import Chem
#       6 from rdkit.Chem.Scaffolds import MurckoScaffold
# ----> 7 from rdkit.Chem import Draw
#       9 smiles_col = 'smiles' if 'smiles' in df.columns else 'Smiles'
#      10 df = df.dropna(subset=[smiles_col])
#
# File ~\anaconda3\envs\cheminfo\Lib\site-packages\rdkit\Chem\Draw\__init__.py:21
#      19 from rdkit import rdBase
#      20 from rdkit.Chem import rdDepictor
# ---> 21 from rdkit.Chem.Draw import rdMolDraw2D
#      22 from rdkit.Chem.Draw.rdMolDraw2D import *
#      25 def _sip_available():
#
# ImportError: DLL load failed while importing rdMolDraw2D: The operation completed successfully.

# %%
pip install rdkit-pypi
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement rdkit-pypi (from versions: none)
# ERROR: No matching distribution found for rdkit-pypi

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv(r"C:\Users\DELL\Downloads\Vitas_PlaF_Screeningdata.csv")

# Display first 5 rows
df.head(5)
# Out:
#    Stars                                           Title  Entry ID  \
# 0    NaN                            sitemap_6I8W_protein         1
# 1    NaN    vsw_Zinc_purchasable-LIGPREP-001-in.maegz:54         2
# 2    NaN                            sitemap_6I8W_protein         3
# 3    NaN  vsw_vitasPart1_plaf-LIGPREP-008-in.maegz:18758         4
# 4    NaN  vsw_vitasPart1_plaf-LIGPREP-004-in.maegz:18104         5
#
#                            Entry Name        Date Added     Date Modified  \
# 0                              6i8w.1  11-10-2025 12:02  11-10-2025 12:02
# 1  vsw_Zinc_purchasable-XP_OUT_1_pv.2  11-10-2025 12:02  11-10-2025 12:02
# 2                              6i8w.1  11-10-2025 12:05  11-10-2025 12:05
# 3   vsw_vitasPart1_plaf-XP_OUT_1_pv.2  11-10-2025 12:05  11-10-2025 12:05
# 4   vsw_vitasPart1_plaf-XP_OUT_1_pv.3  11-10-2025 12:05  11-10-2025 12:05
#
#   receptor created disulfur prepared  grid version  ...  \
# 0     True             True     True       94141.0  ...
# ...

# %%
df.columns.to_list()
# Out:
# ['Stars',
#  'Title',
#  'Entry ID',
#  'Entry Name',
#  'Date Added',
#  'Date Modified',
#  'receptor',
#  'created disulfur',
#  'prepared',
#  'grid version',
#  'Source File Index',
#  'PDB CRYST1 z',
#  'gridbox ligxrange',
#  'gridbox ligyrange',
#  'gridbox ligzrange',
#  'gridbox xcent',
#  'gridbox xrange',
#  'gridbox ycent',
#  'gridbox yrange',
#  'gridbox zcent',
#  'gridbox zrange',
#  'Bend Energy-S-OPLS',
#  'Dihedral Energy-S-OPLS',
#  'El-14 Energy-S-OPLS',
#  'Electrostatic Energy-S-OPLS',
#  'LJ-14 Energy-S-OPLS',
#  'Max Derivative-S-OPLS',
#  'Potential Energy-S-OPLS',
#  'RMS Derivative-S-OPLS',
#  'Stretch Energy-S-OPLS',
#  'Van der Waals Energy-S-OPLS',
#  'target temperature',
#  'PDB CRYST1 a',
#  'PDB CRYST1 alpha',
#  'PDB CRYST1 b',
#  'PDB CRYST1 beta',
#  'PDB CRYST1 c',
#  'PDB CRYST1 gamma',
#  'PDB EXPDTA PH',
#  'PDB EXPDTA TEMPERATURE',
#  'PDB R',
#  'PDB RESOLUTION',
#  'PDB Rfree',
#  'preprocess pH',
#  'grid type',
#  'Source File',
# ...

# %%
# Check for missing values
df.isnull().sum()
# Out:
# Stars         358
# Title           0
# Entry ID        0
# Entry Name      0
# Date Added      0
#              ...
# Memb1 y       356
# Memb1 z       356
# Memb2 x       356
# Memb2 y       356
# Memb2 z       356
# Length: 176, dtype: int64

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
from IPython.display import display, HTML
display(HTML(df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Stars</th>
#       <th>Title</th>
#       <th>Entry ID</th>
#       <th>Entry Name</th>
#       <th>Date Added</th>
#       <th>Date Modified</th>
#       <th>receptor</th>
#       <th>created disulfur</th>
#       <th>prepared</th>
#       <th>grid version</th>
#       <th>Source File Index</th>
#       <th>PDB CRYST1 z</th>
#       <th>gridbox ligxrange</th>
#       <th>gridbox ligyrange</th>
#       <th>gridbox ligzrange</th>
#       <th>gridbox xcent</th>
#       <th>gridbox xrange</th>
#       <th>gridbox ycent</th>
#       <th>gridbox yrange</th>
#       <th>gridbox zcent</th>
#       <th>gridbox zrange</th>
#       <th>Bend Energy-S-OPLS</th>
#       <th>Dihedral Energy-S-OPLS</th>
#       <th>El-14 Energy-S-OPLS</th>
#       <th>Electrostatic Energy-S-OPLS</th>
#       <th>LJ-14 Energy-S-OPLS</th>
#       <th>Max Derivative-S-OPLS</th>
# ...

# %%
df.shape
# Out:
# (358, 176)

# %%
# !pip install rdkit-pypi
# Out:
# ERROR: Could not find a version that satisfies the requirement rdkit-pypi (from versions: none)
# ERROR: No matching distribution found for rdkit-pypi

# %%
# !pip install git+https://github.com/rdkit/rdkit.git
# Out:
# ...
#   Cloning https://github.com/rdkit/rdkit.git to c:\users\dell\appdata\local\temp\pip-req-build-o75wryqn
#   ERROR: Error [WinError 2] The system cannot find the file specified while executing command git version
# ERROR: Cannot find command 'git' - do you have 'git' installed and in your PATH?

# %%
# !pip show rdkit
# Out:
# Name: rdkit
# Version: 2025.3.2
# Summary: A collection of cheminformatics and machine-learning software written in C++ and Python
# Home-page:
# Author:
# Author-email: Greg Landrum <greg.landrum@gmail.com>
# License: BSD-3-Clause
# Location: C:\Users\DELL\anaconda3\envs\cheminfo\Lib\site-packages
# Requires:
# Required-by:

# %%
from rdkit import Chem
print("RDKit works!")
# Out:
# RDKit works!

# %%
from rdkit import Chem
from rdkit.Chem import Descriptors

mol = Chem.MolFromSmiles("CCO")  # ethanol
print("RDKit is working ✅")
print("Molecular weight:", Descriptors.MolWt(mol))
# Out:
# RDKit is working ✅
# Molecular weight: 46.069

# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'

from rdkit import Chem
from rdkit.Chem import Draw, Descriptors
from rdkit.Chem.Scaffolds import MurckoScaffold
def get_scaffold(smiles):
    try:
        mol = Chem.MolFromSmiles(smiles)
        if mol:
            scaffold = MurckoScaffold.GetScaffoldForMol(mol)
            return Chem.MolToSmiles(scaffold)
    except:
        return None

df['scaffold'] = df['smiles'].apply(get_scaffold)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 5
#       2 os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'
#       4 from rdkit import Chem
# ----> 5 from rdkit.Chem import Draw, Descriptors
#       6 from rdkit.Chem.Scaffolds import MurckoScaffold
#       7 def get_scaffold(smiles):
#
# File ~\anaconda3\envs\cheminfo\Lib\site-packages\rdkit\Chem\Draw\__init__.py:21
#      19 from rdkit import rdBase
#      20 from rdkit.Chem import rdDepictor
# ---> 21 from rdkit.Chem.Draw import rdMolDraw2D
#      22 from rdkit.Chem.Draw.rdMolDraw2D import *
#      25 def _sip_available():
#
# ImportError: DLL load failed while importing rdMolDraw2D: The operation completed successfully.

# %%
import os
print(os.environ['PATH'])
# Out:
# C:\Users\DELL\anaconda3\envs\cheminfo;C:\Users\DELL\anaconda3\envs\cheminfo\Library\mingw-w64\bin;C:\Users\DELL\anaconda3\envs\cheminfo\Library\usr\bin;C:\Users\DELL\anaconda3\envs\cheminfo\Library\bin;C:\Users\DELL\anaconda3\envs\cheminfo\Scripts;C:\Users\DELL\anaconda3\envs\cheminfo\bin;C:\Users\DELL\anaconda3\condabin;C:\Program Files (x86)\Common Files\Oracle\Java\java8path;C:\Program Files (x86)\Common Files\Oracle\Java\javapath;C:\Program Files\PerkinElmerInformatics\ChemOffice2021\ChemScript\Lib;C:\Windows\system32;C:\Windows;C:\Windows\System32\Wbem;C:\Windows\System32\WindowsPowerShell\v1.0;C:\Windows\System32\OpenSSH;C:\Program Files (x86)\NVIDIA Corporation\PhysX\Common;C:\Program Files\dotnet;C:\WINDOWS\system32;C:\WINDOWS;C:\WINDOWS\System32\Wbem;C:\WINDOWS\System32\WindowsPowerShell\v1.0;C:\WINDOWS\System32\OpenSSH;C:\Program Files (x86)\MGLTools-1.5.7;C:\Program Files\OpenBabel-2.4.1;C:\Users\DELL\AppData\Local\Microsoft\WindowsApps;C:\Users\DELL\AppData\Local\Programs
# ...

# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'

from rdkit import Chem
from rdkit.Chem import Descriptors
from rdkit.Chem.Scaffolds import MurckoScaffold

def get_scaffold(smiles):
    try:
        mol = Chem.MolFromSmiles(smiles)
        if mol:
            scaffold = MurckoScaffold.GetScaffoldForMol(mol)
            return Chem.MolToSmiles(scaffold)
        else:
            return None
    except Exception as e:
        # Optionally print or log the error for debugging
        # print(f"Error with SMILES {smiles}: {e}")
        return None

# Assuming your DataFrame is called df and has a column 'smiles'
df['scaffold'] = df['smiles'].apply(get_scaffold)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 22
#      19         return None
#      21 # Assuming your DataFrame is called df and has a column 'smiles'
# ---> 22 df['scaffold'] = df['smiles'].apply(get_scaffold)
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# To see available sheet names
df = pd.read_csv(r"C:\Users\DELL\Downloads\Vitas_PlaF_Screeningdata.csv")

# %%
df.head(5)
# Out:
#    Stars                                           Title  Entry ID  \
# 0    NaN                            sitemap_6I8W_protein         1
# 1    NaN    vsw_Zinc_purchasable-LIGPREP-001-in.maegz:54         2
# 2    NaN                            sitemap_6I8W_protein         3
# 3    NaN  vsw_vitasPart1_plaf-LIGPREP-008-in.maegz:18758         4
# 4    NaN  vsw_vitasPart1_plaf-LIGPREP-004-in.maegz:18104         5
#
#                            Entry Name        Date Added     Date Modified  \
# 0                              6i8w.1  11-10-2025 12:02  11-10-2025 12:02
# 1  vsw_Zinc_purchasable-XP_OUT_1_pv.2  11-10-2025 12:02  11-10-2025 12:02
# 2                              6i8w.1  11-10-2025 12:05  11-10-2025 12:05
# 3   vsw_vitasPart1_plaf-XP_OUT_1_pv.2  11-10-2025 12:05  11-10-2025 12:05
# 4   vsw_vitasPart1_plaf-XP_OUT_1_pv.3  11-10-2025 12:05  11-10-2025 12:05
#
#   receptor created disulfur prepared  grid version  ...  \
# 0     True             True     True       94141.0  ...
# ...

# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'

from rdkit import Chem
from rdkit.Chem import Descriptors
from rdkit.Chem.Scaffolds import MurckoScaffold

def get_scaffold(smiles):
    try:
        mol = Chem.MolFromSmiles(smiles)
        if mol:
            scaffold = MurckoScaffold.GetScaffoldForMol(mol)
            return Chem.MolToSmiles(scaffold)
        else:
            return None
    except Exception as e:
        # Optionally print or log the error for debugging
        # print(f"Error with SMILES {smiles}: {e}")
        return None

# Assuming your DataFrame is called df and has a column 'smiles'
df['scaffold'] = df['smiles'].apply(get_scaffold)

# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'

from rdkit import Chem
from rdkit.Chem import Descriptors
from rdkit.Chem.Scaffolds import MurckoScaffold

def get_scaffold(smiles):
    try:
        mol = Chem.MolFromSmiles(smiles)
        if mol:
            scaffold = MurckoScaffold.GetScaffoldForMol(mol)
            return Chem.MolToSmiles(scaffold)
        else:
            return None
    except Exception as e:
        # Optionally print or log the error for debugging
        # print(f"Error with SMILES {smiles}: {e}")
        return None

# Assuming your DataFrame is called df and has a column 'smiles'
df['scaffold'] = df['Smiles'].apply(get_scaffold)

# %%
df.head(5)
# Out:
#    Stars                                           Title  Entry ID  \
# 0    NaN                            sitemap_6I8W_protein         1
# 1    NaN    vsw_Zinc_purchasable-LIGPREP-001-in.maegz:54         2
# 2    NaN                            sitemap_6I8W_protein         3
# 3    NaN  vsw_vitasPart1_plaf-LIGPREP-008-in.maegz:18758         4
# 4    NaN  vsw_vitasPart1_plaf-LIGPREP-004-in.maegz:18104         5
#
#                            Entry Name        Date Added     Date Modified  \
# 0                              6i8w.1  11-10-2025 12:02  11-10-2025 12:02
# 1  vsw_Zinc_purchasable-XP_OUT_1_pv.2  11-10-2025 12:02  11-10-2025 12:02
# 2                              6i8w.1  11-10-2025 12:05  11-10-2025 12:05
# 3   vsw_vitasPart1_plaf-XP_OUT_1_pv.2  11-10-2025 12:05  11-10-2025 12:05
# 4   vsw_vitasPart1_plaf-XP_OUT_1_pv.3  11-10-2025 12:05  11-10-2025 12:05
#
#   receptor created disulfur prepared  grid version  ...  Saltdata  \
# ...

# %%
df['scaffold'].notna().sum()     # how many scaffolds generated
df['scaffold'].nunique()         # how many unique scaffolds
# Out:
# 260

# %%
df['scaffold'].nunique()
# Out:
# 260

# %%
df['scaffold'].notna().sum()
# Out:
# np.int64(353)

# %%
unique_scaffolds = df['scaffold'].nunique()
print(f"Number of unique scaffolds: {unique_scaffolds}")
# Out:
# Number of unique scaffolds: 260

# %%
top_scaffolds = df['scaffold'].value_counts().head(353)
print(top_scaffolds)
# Out:
# scaffold
# O=C(CCC(=O)OCC(=O)c1ccccc1)Nc1ccccc1                       9
# c1ccc(-c2ccsc2)cc1                                         6
# O=C(NCc1ccccc1)Nc1ccccc1                                   6
# O=C(Nc1ccccc1)c1cccc(N2C(=O)C3C4C=CC(C5CC45)C3C2=O)c1      5
# C1=NC(c2ccccc2)Nc2scc(-c3ccccc3)c21                        4
#                                                           ..
# O=C(N/N=C/c1ccccn1)c1cc(-c2ccc3ccccc3c2)n[nH]1             1
# O=C(C=C1Nc2ccccc2N1)Cc1ccccc1                              1
# O=C(c1ccccc1)N1CCC=N1                                      1
# O=C(Oc1cccc2ccccc12)c1ccc(N2C(=O)C3C4C=CC(C4)C3C2=O)cc1    1
# O=C1CC(c2ccccc2)Cc2nc(Nc3ncc4ccccc4n3)ncc21                1
# Name: count, Length: 260, dtype: int64

# %%
from rdkit import Chem

top_scaffolds_smiles = df['scaffold'].value_counts().head(10).index.tolist()

for i, smi in enumerate(top_scaffolds_smiles):
    mol = Chem.MolFromSmiles(smi)
    if mol:
        filename = f"scaffold_{i+1}.svg"
        Chem.MolToFile(mol, filename, size=(300,300), kekulize=True)
        print(f"Saved {filename}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 9
#       7 if mol:
#       8     filename = f"scaffold_{i+1}.svg"
# ----> 9     Chem.MolToFile(mol, filename, size=(300,300), kekulize=True)
#      10     print(f"Saved {filename}")
#
# AttributeError: module 'rdkit.Chem' has no attribute 'MolToFile'

# %%
top_scaffolds_smiles = df['scaffold'].value_counts().head(10).index.tolist()

with open("top_scaffolds.smi", "w") as f:
    for smi in top_scaffolds_smiles:
        f.write(smi + "\n")

print("Top scaffolds saved to 'top_scaffolds.smi'. Upload this file to molview.org or PubChem Sketcher to view the molecules.")
# Out:
# Top scaffolds saved to 'top_scaffolds.smi'. Upload this file to molview.org or PubChem Sketcher to view the molecules.

# %%
print("Top 10 scaffolds with counts:")
print(df['scaffold'].value_counts().head(10))
# Out:
# Top 10 scaffolds with counts:
# scaffold
# O=C(CCC(=O)OCC(=O)c1ccccc1)Nc1ccccc1                     9
# c1ccc(-c2ccsc2)cc1                                       6
# O=C(NCc1ccccc1)Nc1ccccc1                                 6
# O=C(Nc1ccccc1)c1cccc(N2C(=O)C3C4C=CC(C5CC45)C3C2=O)c1    5
# C1=NC(c2ccccc2)Nc2scc(-c3ccccc3)c21                      4
# O=C1CC(c2ccccc2)c2ccc3ccccc3c2N1                         4
# O=C(COc1ccc(N2CCCC2=O)cc1)Nc1ccccc1                      4
# O=C(Nc1ccccc1)c1conc1-c1ccccc1                           4
# O=C(Nc1cc(-c2ccccc2)cs1)C1CCCO1                          4
# O=C(Nc1ccccc1)C1CC(=O)N(c2ccccc2)C1                      4
# Name: count, dtype: int64

# %%
print("Top 10 scaffolds with counts:")
print(df['scaffold'].value_counts().head(20))
# Out:
# Top 10 scaffolds with counts:
# scaffold
# O=C(CCC(=O)OCC(=O)c1ccccc1)Nc1ccccc1                     9
# c1ccc(-c2ccsc2)cc1                                       6
# O=C(NCc1ccccc1)Nc1ccccc1                                 6
# O=C(Nc1ccccc1)c1cccc(N2C(=O)C3C4C=CC(C5CC45)C3C2=O)c1    5
# C1=NC(c2ccccc2)Nc2scc(-c3ccccc3)c21                      4
# O=C1CC(c2ccccc2)c2ccc3ccccc3c2N1                         4
# O=C(COc1ccc(N2CCCC2=O)cc1)Nc1ccccc1                      4
# O=C(Nc1ccccc1)c1conc1-c1ccccc1                           4
# O=C(Nc1cc(-c2ccccc2)cs1)C1CCCO1                          4
# O=C(Nc1ccccc1)C1CC(=O)N(c2ccccc2)C1                      4
# O=C(Nc1ccccc1)Nc1c[nH]n(-c2ccccc2)c1=O                   4
# O=C(/C=C\c1c[nH]nc1-c1ccccc1)Nc1ccccc1                   4
# O=C(Nc1ccccc1)Nc1ccccc1                                  4
# O=C1CC(c2ccccc2)C2=C(CC(c3ccccc3)CC2=O)N1                3
# O=C(/C=C\c1c[nH]nc1-c1ccccc1)NCc1ccccc1                  3
# ...

# %%
import pandas as pd

# Select the key columns you care about
important_cols = [
    'Smiles', 'scaffold', 'docking score', 'XP GScore', 'glide emodel',
    'glide energy', 'mol MW', 'logP', 'H_Donors', 'H_Acceptors',
    'PSA-1', 'Rotatable_Bonds'
]

# Keep only those that actually exist in your file
important_cols = [c for c in important_cols if c in df.columns]

core_df = df[important_cols].copy()

# Drop rows where SMILES or docking score is missing
core_df = core_df.dropna(subset=['Smiles', 'docking score'])
core_df.head()
# Out:
#                                               Smiles  \
# 3      N#Cc1c(NC(=O)CC(CC(=O)O)C)sc(c1c1ccc(cc1)OC)C
# 4         N#Cc1c(NC(=O)CCCC(=O)O)sc(c1c1ccc(cc1)OC)C
# 5  O=C(OCC(=O)c1ccc(cc1Cl)Cl)CCC(=O)Nc1cc(ccc1Cl)...
# 6  COc1cccc(c1)C(=O)COC(=O)CCC(=O)Nc1cccc(c1)C(F)...
# 7  O=C(Nc1cc(ccc1Cl)C(F)(F)F)COc1ccc(cc1)N1CC(CC1...
#
#                                scaffold  docking score  XP GScore  \
# 3                    c1ccc(-c2ccsc2)cc1     -12.248680 -12.251980
# 4                    c1ccc(-c2ccsc2)cc1     -12.102245 -12.104945
# 5  O=C(CCC(=O)OCC(=O)c1ccccc1)Nc1ccccc1     -11.960127 -11.960127
# 6  O=C(CCC(=O)OCC(=O)c1ccccc1)Nc1ccccc1     -11.861694 -11.861694
# 7   O=C(COc1ccc(N2CCCC2=O)cc1)Nc1ccccc1     -11.828015 -11.828015
#
#    glide emodel  glide energy   mol MW   logP  H_Donors  H_Acceptors   PSA-1  \
# 3    -50.354610    -34.299883  372.438  2.610       2.0          4.0  127.66
# 4    -44.314245    -29.080071  358.411  2.263       2.0          4.0  127.66
# ...

# %%
import pandas as pd

# Choose your identifier columns (only those that exist)
id_cols = ['Entry ID', 'compound code', 'zinc_id', 'Compound_Names', 'ID']
id_cols = [c for c in id_cols if c in df.columns]

# Important property columns (only those that exist)
prop_cols = [
    'Smiles', 'scaffold', 'docking score', 'XP GScore', 'glide emodel',
    'glide energy', 'mol MW', 'logP', 'H_Donors', 'H_Acceptors',
    'PSA-1', 'Rotatable_Bonds'
]
prop_cols = [c for c in prop_cols if c in df.columns]

# Combine identifiers + properties for full dataset
final_cols = id_cols + prop_cols

# Filter dataframe and drop missing critical data
core_df = df[final_cols].dropna(subset=['Smiles', 'docking score']).copy()

# Add ranking based on docking score (lower is better)
core_df['Rank'] = core_df['docking score'].rank(method='min', ascending=True).astype(int)

# Save full dataset with rank
core_df.to_excel("All_Scaffold_Analysis_With_Rank.xlsx", index=False)

# Additionally, save the best molecule per scaffold with IDs and rank
best_per_scaffold = core_df.loc[core_df.groupby('scaffold')['docking score'].idxmin()].copy()
best_per_scaffold = best_per_scaffold.sort_values(by='docking score', ascending=True)

best_per_scaffold.to_excel("Best_Per_Scaffold_With_Rank.xlsx", index=False)

print("✅ Files saved:")
print("- 'All_Scaffold_Analysis_With_Rank.xlsx' (full data with Rank)")
print("- 'Best_Per_Scaffold_With_Rank.xlsx' (best compound per scaffold with Rank)")
# Out:
# ✅ Files saved:
# - 'All_Scaffold_Analysis_With_Rank.xlsx' (full data with Rank)
# - 'Best_Per_Scaffold_With_Rank.xlsx' (best compound per scaffold with Rank)

# %%
from IPython.display import display, HTML

html = core_top20_df.to_html(index=False)

scrollable_html = f'''
<div style="max-height:400px; overflow-y:auto; border:1px solid lightgray;">
    {html}
</div>
'''

display(HTML(scrollable_html))
# Out:
# <div style="max-height:400px; overflow-y:auto; border:1px solid lightgray;">
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Smiles</th>
#       <th>scaffold</th>
#       <th>docking score</th>
#       <th>XP GScore</th>
#       <th>glide emodel</th>
#       <th>glide energy</th>
#       <th>mol MW</th>
#       <th>logP</th>
#       <th>H_Donors</th>
#       <th>H_Acceptors</th>
#       <th>PSA-1</th>
#       <th>Rotatable_Bonds</th>
#       <th>Compound_Names</th>
#       <th>ID</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>N#Cc1c(NC(=O)CC(CC(=O)O)C)sc(c1c1ccc(cc1)OC)C</td>
#       <td>c1ccc(-c2ccsc2)cc1</td>
#       <td>-12.248680</td>
#       <td>-12.251980</td>
#       <td>-50.354610</td>
#       <td>-34.299883</td>
#       <td>372.438</td>
#       <td>2.610</td>
#       <td>2.0</td>
#       <td>4.0</td>
#       <td>127.66</td>
#       <td>5.0</td>
# ...

# %%
from IPython.display import display, HTML

# Define your ID column name here
id_col = 'ID'  # change this if your ID column has a different name

# List of columns to display (make sure all exist in df)
important_cols = [
    'Smiles', 'scaffold', 'docking score', 'XP GScore', 'glide emodel',
    'glide energy', 'mol MW', 'logP', 'H_Donors', 'H_Acceptors',
    'PSA-1', 'Rotatable_Bonds'
]

# Filter only existing columns in your dataframe
important_cols = [c for c in important_cols if c in df.columns]

# Ensure ID column exists
if id_col in df.columns:
    # Make new column order: ID first, then Smiles, scaffold, then rest (without duplication)
    cols_order = [id_col, 'Smiles', 'scaffold'] + [c for c in important_cols if c not in ['Smiles', 'scaffold']]
else:
    print(f"Warning: ID column '{id_col}' not found. Showing without ID.")
    cols_order = ['Smiles', 'scaffold'] + important_cols

# Create filtered DataFrame with top 20 scaffolds only
core_top20_df = df[df['scaffold'].isin(top_20_scaffolds)][cols_order]

# Drop rows missing essential info if needed
core_top20_df = core_top20_df.dropna(subset=['Smiles', 'docking score'])

# Create scrollable HTML table
html = core_top20_df.to_html(index=False)

scrollable_html = f'''
<div style="max-height:400px; overflow-y:auto; border:1px solid lightgray;">
    {html}
</div>
'''

display(HTML(scrollable_html))
# Out:
# <div style="max-height:400px; overflow-y:auto; border:1px solid lightgray;">
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>ID</th>
#       <th>Smiles</th>
#       <th>scaffold</th>
#       <th>docking score</th>
#       <th>XP GScore</th>
#       <th>glide emodel</th>
#       <th>glide energy</th>
#       <th>mol MW</th>
#       <th>logP</th>
#       <th>H_Donors</th>
#       <th>H_Acceptors</th>
#       <th>PSA-1</th>
#       <th>Rotatable_Bonds</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>STK471112</td>
#       <td>N#Cc1c(NC(=O)CC(CC(=O)O)C)sc(c1c1ccc(cc1)OC)C</td>
#       <td>c1ccc(-c2ccsc2)cc1</td>
#       <td>-12.248680</td>
#       <td>-12.251980</td>
#       <td>-50.354610</td>
#       <td>-34.299883</td>
#       <td>372.438</td>
#       <td>2.610</td>
#       <td>2.0</td>
#       <td>4.0</td>
#       <td>127.66</td>
#       <td>5.0</td>
#     </tr>
#     <tr>
#       <td>STK455006</td>
# ...

# %%
output_filename = 'top20_scaffolds_with_params.xlsx'
core_top20_df.to_excel(output_filename, index=False)
print(f"Saved output to {output_filename}")
# Out:
# Saved output to top20_scaffolds_with_params.xlsx

# %%
best_scaffolds = df.groupby('scaffold')['docking score'].mean().sort_values().head(10)
display(best_scaffolds)
# Out:
# scaffold
# O=S(=O)(Nc1ccccc1)c1ccc(NC(=S)Nc2ccccc2)cc1   -11.683469
# O=C1N/C(=N\c2ccccc2)S/C1=C\c1c[nH]c2ccccc12   -11.617317
# S=C(Nc1ccccc1)N1CCc2ccccc2C1                  -11.543981
# O=C(NCc1nc(-c2ccccc2)no1)Nc1cccc2ccccc12      -11.476779
# O=C(CSc1ccccc1)Nc1cc(-c2ccccc2)cs1            -11.358076
# O=C(CC1C(=O)NCCN1C(=O)Nc1ccccc1)Nc1ccccc1     -11.294418
# c1ccc(-c2ccsc2)cc1                            -11.292539
# O=C(COc1ccc(-c2ncno2)cc1)Nc1ccccc1            -11.144917
# O=C(Nc1ccccc1)C1CC(=O)N(Cc2ccccc2)C1          -11.075165
# O=C(CCC(=O)N1CCN(c2ccccc2)CC1)Nc1ccccc1       -11.058820
# Name: docking score, dtype: float64

# %%
# ✅ Filter for drug-like molecules (Lipinski rules)
druglike = df[
    (df['H_Donors'] <= 5) &
    (df['H_Acceptors'] <= 10) &
    (df['logP'] <= 5) &
    (df['mol MW'] <= 500)
].copy()

# ✅ Sort by best (lowest) docking score
druglike = druglike.sort_values(by='docking score', ascending=True)

# ✅ Select only the top 10
druglike_top10 = druglike.head(10)

# ✅ Choose columns to display (you can adjust this list)
columns_to_show = [
    'ID', 'Smiles', 'scaffold', 'docking score', 'XP GScore', 'glide emodel',
    'glide energy', 'mol MW', 'logP', 'H_Donors', 'H_Acceptors', 'PSA-1', 'Rotatable_Bonds'
]

# ✅ Keep only columns that exist
columns_to_show = [c for c in columns_to_show if c in druglike_top10.columns]

# ✅ Display top 10 druglike molecules in a scrollable table
from IPython.display import HTML

scrollable_html = (
    druglike_top10[columns_to_show]
    .style.set_table_attributes('style="max-height:400px; overflow-y:auto; display:block;"')
    .to_html()
)
display(HTML(scrollable_html))
# Out:
# <style type="text/css">
# </style>
# <table id="T_b4c83" style="max-height:400px; overflow-y:auto; display:block;">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b4c83_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_b4c83_level0_col1" class="col_heading level0 col1" >Smiles</th>
#       <th id="T_b4c83_level0_col2" class="col_heading level0 col2" >scaffold</th>
#       <th id="T_b4c83_level0_col3" class="col_heading level0 col3" >docking score</th>
#       <th id="T_b4c83_level0_col4" class="col_heading level0 col4" >XP GScore</th>
#       <th id="T_b4c83_level0_col5" class="col_heading level0 col5" >glide emodel</th>
#       <th id="T_b4c83_level0_col6" class="col_heading level0 col6" >glide energy</th>
#       <th id="T_b4c83_level0_col7" class="col_heading level0 col7" >mol MW</th>
#       <th id="T_b4c83_level0_col8" class="col_heading level0 col8" >logP</th>
# ...

# %%
print(df.columns)  # Confirm scaffold is here
print(df.head())   # Confirm scaffold values exist
# Out:
# Index(['Stars', 'Title', 'Entry ID', 'Entry Name', 'Date Added',
#        'Date Modified', 'receptor', 'created disulfur', 'prepared',
#        'grid version',
#        ...
#        'URL', 'Saltdata', 'Special_collections', 'stereochem', 'Memb1 x',
#        'Memb1 y', 'Memb1 z', 'Memb2 x', 'Memb2 y', 'Memb2 z'],
#       dtype='object', length=176)
#    Stars                                           Title  Entry ID  \
# 0    NaN                            sitemap_6I8W_protein         1
# 1    NaN    vsw_Zinc_purchasable-LIGPREP-001-in.maegz:54         2
# 2    NaN                            sitemap_6I8W_protein         3
# 3    NaN  vsw_vitasPart1_plaf-LIGPREP-008-in.maegz:18758         4
# 4    NaN  vsw_vitasPart1_plaf-LIGPREP-004-in.maegz:18104         5
#
#                            Entry Name        Date Added     Date Modified  \
# 0                              6i8w.1  11-10-2025 12:02  11-10-2025 12:02
# ...

# %%
from rdkit import Chem
from rdkit.Chem.Scaffolds import MurckoScaffold

def get_scaffold(smiles):
    try:
        mol = Chem.MolFromSmiles(smiles)
        if mol:
            scaffold = MurckoScaffold.GetScaffoldForMol(mol)
            return Chem.MolToSmiles(scaffold)
        else:
            return None
    except Exception as e:
        return None

# Add scaffold column
df['scaffold'] = df['Smiles'].apply(get_scaffold)  # use exact SMILES column name

# %%
print(df[['Smiles', 'scaffold']].head())
scaffold_counts = df['scaffold'].value_counts()
print(scaffold_counts.head(20))
# Out:
#                                           Smiles            scaffold
# 0                                            NaN                None
# 1                                            NaN                None
# 2                                            NaN                None
# 3  N#Cc1c(NC(=O)CC(CC(=O)O)C)sc(c1c1ccc(cc1)OC)C  c1ccc(-c2ccsc2)cc1
# 4     N#Cc1c(NC(=O)CCCC(=O)O)sc(c1c1ccc(cc1)OC)C  c1ccc(-c2ccsc2)cc1
# scaffold
# O=C(CCC(=O)OCC(=O)c1ccccc1)Nc1ccccc1                     9
# c1ccc(-c2ccsc2)cc1                                       6
# O=C(NCc1ccccc1)Nc1ccccc1                                 6
# O=C(Nc1ccccc1)c1cccc(N2C(=O)C3C4C=CC(C5CC45)C3C2=O)c1    5
# C1=NC(c2ccccc2)Nc2scc(-c3ccccc3)c21                      4
# O=C1CC(c2ccccc2)c2ccc3ccccc3c2N1                         4
# O=C(COc1ccc(N2CCCC2=O)cc1)Nc1ccccc1                      4
# O=C(Nc1ccccc1)c1conc1-c1ccccc1                           4
# O=C(Nc1cc(-c2ccccc2)cs1)C1CCCO1                          4
# ...

# %%
df[['Smiles', 'scaffold', 'docking score']].head(10)
scaffold_counts = df['scaffold'].value_counts()
print(scaffold_counts.head(10))
# Out:
# scaffold
# O=C(CCC(=O)OCC(=O)c1ccccc1)Nc1ccccc1                     9
# c1ccc(-c2ccsc2)cc1                                       6
# O=C(NCc1ccccc1)Nc1ccccc1                                 6
# O=C(Nc1ccccc1)c1cccc(N2C(=O)C3C4C=CC(C5CC45)C3C2=O)c1    5
# C1=NC(c2ccccc2)Nc2scc(-c3ccccc3)c21                      4
# O=C1CC(c2ccccc2)c2ccc3ccccc3c2N1                         4
# O=C(COc1ccc(N2CCCC2=O)cc1)Nc1ccccc1                      4
# O=C(Nc1ccccc1)c1conc1-c1ccccc1                           4
# O=C(Nc1cc(-c2ccccc2)cs1)C1CCCO1                          4
# O=C(Nc1ccccc1)C1CC(=O)N(c2ccccc2)C1                      4
# Name: count, dtype: int64

# %%
df[['Smiles', 'scaffold', 'docking score']].head(10)
# Out:
#                                               Smiles  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3      N#Cc1c(NC(=O)CC(CC(=O)O)C)sc(c1c1ccc(cc1)OC)C
# 4         N#Cc1c(NC(=O)CCCC(=O)O)sc(c1c1ccc(cc1)OC)C
# 5  O=C(OCC(=O)c1ccc(cc1Cl)Cl)CCC(=O)Nc1cc(ccc1Cl)...
# 6  COc1cccc(c1)C(=O)COC(=O)CCC(=O)Nc1cccc(c1)C(F)...
# 7  O=C(Nc1cc(ccc1Cl)C(F)(F)F)COc1ccc(cc1)N1CC(CC1...
# 8  S=C(Nc1cccc(c1)C(F)(F)F)Nc1ccc(cc1)S(=O)(=O)Nc...
# 9  OC(COc1ccc(cc1)NC(=O)c1c(C)onc1c1ccccc1)CNC(C)...
#
#                                       scaffold  docking score
# 0                                         None            NaN
# 1                                         None      -8.665487
# 2                                         None            NaN
# 3                           c1ccc(-c2ccsc2)cc1     -12.248680
# 4                           c1ccc(-c2ccsc2)cc1     -12.102245
# ...

# %%
scaffold_counts = df['scaffold'].value_counts()
print(scaffold_counts.head(10))
# Out:
# scaffold
# O=C(CCC(=O)OCC(=O)c1ccccc1)Nc1ccccc1                     9
# c1ccc(-c2ccsc2)cc1                                       6
# O=C(NCc1ccccc1)Nc1ccccc1                                 6
# O=C(Nc1ccccc1)c1cccc(N2C(=O)C3C4C=CC(C5CC45)C3C2=O)c1    5
# C1=NC(c2ccccc2)Nc2scc(-c3ccccc3)c21                      4
# O=C1CC(c2ccccc2)c2ccc3ccccc3c2N1                         4
# O=C(COc1ccc(N2CCCC2=O)cc1)Nc1ccccc1                      4
# O=C(Nc1ccccc1)c1conc1-c1ccccc1                           4
# O=C(Nc1cc(-c2ccccc2)cs1)C1CCCO1                          4
# O=C(Nc1ccccc1)C1CC(=O)N(c2ccccc2)C1                      4
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

scaffold_counts.head(20).plot(kind='bar', figsize=(12,6), color='yellow')
plt.title('Top 20 Most Common Scaffolds')
plt.xlabel('Scaffold (Murcko SMILES)')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %%
best_scaffolds = df.groupby('scaffold')['docking score'].mean().sort_values().head(10)
print(best_scaffolds)
# Out:
# scaffold
# O=S(=O)(Nc1ccccc1)c1ccc(NC(=S)Nc2ccccc2)cc1   -11.683469
# O=C1N/C(=N\c2ccccc2)S/C1=C\c1c[nH]c2ccccc12   -11.617317
# S=C(Nc1ccccc1)N1CCc2ccccc2C1                  -11.543981
# O=C(NCc1nc(-c2ccccc2)no1)Nc1cccc2ccccc12      -11.476779
# O=C(CSc1ccccc1)Nc1cc(-c2ccccc2)cs1            -11.358076
# O=C(CC1C(=O)NCCN1C(=O)Nc1ccccc1)Nc1ccccc1     -11.294418
# c1ccc(-c2ccsc2)cc1                            -11.292539
# O=C(COc1ccc(-c2ncno2)cc1)Nc1ccccc1            -11.144917
# O=C(Nc1ccccc1)C1CC(=O)N(Cc2ccccc2)C1          -11.075165
# O=C(CCC(=O)N1CCN(c2ccccc2)CC1)Nc1ccccc1       -11.058820
# Name: docking score, dtype: float64

# %%
best_scaffolds.plot(kind='barh', figsize=(10,5), color='orange')
plt.title('Top 10 Scaffolds with Best (Lowest) Average Docking Scores')
plt.xlabel('Average Docking Score')
plt.ylabel('Scaffold')
plt.gca().invert_yaxis()
plt.show()

# %%
top_scaffold = best_scaffolds.index[0]
subset = df[df['scaffold'] == top_scaffold]
subset[['ID', 'Smiles', 'docking score']].sort_values('docking score').head()
# Out:
#           ID                                             Smiles  docking score
# 8  STK495100  S=C(Nc1cccc(c1)C(F)(F)F)Nc1ccc(cc1)S(=O)(=O)Nc...     -11.683469

# %%
# Clean the Smiles column
df = df[df['Smiles'].notnull()]  # remove NaN rows
df['Smiles'] = df['Smiles'].astype(str)

# %%
from rdkit import Chem
from rdkit.Chem import AllChem

def get_fingerprint(smiles):
    try:
        mol = Chem.MolFromSmiles(smiles)
        if mol:
            return AllChem.GetMorganFingerprintAsBitVect(mol, radius=2, nBits=1024)
        else:
            return None
    except Exception as e:
        # Optional: print bad SMILES for debugging
        # print(smiles, e)
        return None

df['fingerprint'] = df['Smiles'].apply(get_fingerprint)
df = df[df['fingerprint'].notnull()]

# %%
bad_smiles = df[df['Smiles'].apply(lambda s: Chem.MolFromSmiles(str(s)) is None)]
bad_smiles[['Smiles']].head()
# Out:
# Empty DataFrame
# Columns: [Smiles]
# Index: []

# %%
# Check basic info about Smiles column
print("Total rows:", len(df))
print("Unique SMILES:", df['Smiles'].nunique())
print("Missing SMILES:", df['Smiles'].isna().sum())

# Preview some entries
df['Smiles'].head(10)
# Out:
# Total rows: 353
# Unique SMILES: 353
# Missing SMILES: 0
# 3         N#Cc1c(NC(=O)CC(CC(=O)O)C)sc(c1c1ccc(cc1)OC)C
# 4            N#Cc1c(NC(=O)CCCC(=O)O)sc(c1c1ccc(cc1)OC)C
# 5     O=C(OCC(=O)c1ccc(cc1Cl)Cl)CCC(=O)Nc1cc(ccc1Cl)...
# 6     COc1cccc(c1)C(=O)COC(=O)CCC(=O)Nc1cccc(c1)C(F)...
# 7     O=C(Nc1cc(ccc1Cl)C(F)(F)F)COc1ccc(cc1)N1CC(CC1...
# 8     S=C(Nc1cccc(c1)C(F)(F)F)Nc1ccc(cc1)S(=O)(=O)Nc...
# 9     OC(COc1ccc(cc1)NC(=O)c1c(C)onc1c1ccccc1)CNC(C)...
# 10               N#Cc1c(NC(=O)CCCC(=O)O)sc(c1c1ccccc1)C
# 11    Fc1ccc(cc1)/N=C/1\NC(=O)/C(=C/c2c[nH]c3c2cccc3...
# 12             COC(=O)Cc1ccc(cc1)NC(=S)N1CCc2c(C1)cccc2
# Name: Smiles, dtype: object

# %%
from rdkit import Chem
from rdkit.Chem import AllChem
import numpy as np

def get_fingerprint(smiles):
    try:
        mol = Chem.MolFromSmiles(smiles)
        if mol:
            # Morgan fingerprint (ECFP4) as a numpy array
            fp = AllChem.GetMorganFingerprintAsBitVect(mol, radius=2, nBits=1024)
            arr = np.zeros((1,))
            AllChem.DataStructs.ConvertToNumpyArray(fp, arr)
            return arr
        else:
            return None
    except Exception:
        return None

# Apply safely
df['fingerprint'] = df['Smiles'].apply(get_fingerprint)

# Drop invalid fingerprints if any
df = df[df['fingerprint'].notnull()]

print("✅ Fingerprints generated for", len(df), "molecules.")
# Out:
# ✅ Fingerprints generated for 353 molecules.

# %%
from rdkit import Chem, DataStructs
from rdkit.Chem import AllChem

def get_rdkit_fingerprint(smiles):
    try:
        mol = Chem.MolFromSmiles(smiles)
        if mol:
            return AllChem.GetMorganFingerprintAsBitVect(mol, radius=2, nBits=1024)
        else:
            return None
    except Exception:
        return None

# 👇 this line actually creates the column
df['rdkit_fp'] = df['Smiles'].apply(get_rdkit_fingerprint)

# remove any failed ones (should be zero, but just in case)
df = df[df['rdkit_fp'].notnull()]

print("✅ RDKit fingerprints created for", len(df), "molecules.")
print(df.columns[-5:])  # to confirm 'rdkit_fp' exists
# Out:
# ✅ RDKit fingerprints created for 353 molecules.
# Index(['Memb2 y', 'Memb2 z', 'scaffold', 'fingerprint', 'rdkit_fp'], dtype='object')

# %%
from rdkit import DataStructs

# pick a reference molecule (you can change the index)
ref_fp = df['rdkit_fp'].iloc[0]

# compute similarity to all others
df['similarity_to_first'] = df['rdkit_fp'].apply(
    lambda fp: DataStructs.TanimotoSimilarity(ref_fp, fp)
)

# view top 10 most similar molecules
similar_mols = df[['ID', 'Smiles', 'similarity_to_first']].sort_values(
    by='similarity_to_first', ascending=False
).head(10)

similar_mols
# Out:
#             ID                                             Smiles  \
# 3    STK471112      N#Cc1c(NC(=O)CC(CC(=O)O)C)sc(c1c1ccc(cc1)OC)C
# 4    STK455006         N#Cc1c(NC(=O)CCCC(=O)O)sc(c1c1ccc(cc1)OC)C
# 226  STK465078           N#Cc1c(NC(=O)CCC(=O)O)sc(c1c1ccc(cc1)F)C
# 95   STK471158  N#Cc1c(NC(=O)C2C3C=CC(C2C(=O)O)C3)sc(c1c1ccc(c...
# 10   STK424145             N#Cc1c(NC(=O)CCCC(=O)O)sc(c1c1ccccc1)C
# 13   STK468662          N#Cc1c(NC(=O)CCCC(=O)O)sc(c1c1ccc(cc1)F)C
# 21   STK486039           N#Cc1c(NC(=O)C2CCCO2)sc(c1c1ccc(cc1)OC)C
# 47   STK468396            N#Cc1c(NC(=O)CCc2ccccc2)sc(c1c1ccccc1)C
# 16   STK450304            N#Cc1c(NC(=O)CSc2ccccc2)sc(c1c1ccccc1)C
# 43   STK451669                N#Cc1c(NC(=O)C2CCC2)sc(c1c1ccccc1)C
#
#      similarity_to_first
# 3               1.000000
# 4               0.732143
# 226             0.576271
# 95              0.569231
# 10              0.559322
# 13              0.557377
# 21              0.553846
# 47              0.533333
# ...

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# compute pairwise Tanimoto similarity
n = 30  # for visualization, use a subset (30 molecules)
fps = list(df['rdkit_fp'].iloc[:n])
sim_matrix = np.zeros((n, n))

for i in range(n):
    for j in range(n):
        sim_matrix[i, j] = DataStructs.TanimotoSimilarity(fps[i], fps[j])

# plot
plt.figure(figsize=(10, 8))
sns.heatmap(sim_matrix, cmap='viridis')
plt.title("Tanimoto Similarity Heatmap (Top 30 Molecules)")
plt.xlabel("Molecule Index")
plt.ylabel("Molecule Index")
plt.show()

# %%
from scipy.cluster.hierarchy import linkage, dendrogram
import matplotlib.pyplot as plt
import numpy as np

# Assume 'sim_matrix' is your similarity matrix (numpy array or pandas dataframe)
# Convert similarity to distance matrix
distance_matrix = 1 - sim_matrix

# Perform hierarchical clustering (using 'average' linkage method)
linked = linkage(distance_matrix, method='average')

# Plot dendrogram
plt.figure(figsize=(10, 7))
dendrogram(linked,
           orientation='top',
           labels=range(len(sim_matrix)),
           distance_sort='descending',
           show_leaf_counts=True)
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Molecule Index')
plt.ylabel('Distance (1 - Tanimoto Similarity)')
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_28220\3535401273.py:10: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   linked = linkage(distance_matrix, method='average')

# %%
import numpy as np
from scipy.spatial.distance import pdist, squareform
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster

# Assume fingerprints are stored in df['rdkit_fp'] as RDKit ExplicitBitVect objects

# Convert fingerprints to numpy bit vectors for distance calculation
fps_array = []
from rdkit.DataStructs import ConvertToNumpyArray

for fp in df['rdkit_fp']:
    arr = np.zeros((1,))
    ConvertToNumpyArray(fp, arr)
    fps_array.append(arr)

fps_array = np.array(fps_array)

# Calculate distance matrix (1 - Tanimoto similarity)
def tanimoto_distance(x, y):
    from rdkit.DataStructs import TanimotoSimilarity
    # convert numpy arrays back to ExplicitBitVect
    from rdkit.DataStructs import ExplicitBitVect
    # Need to create fingerprints for TanimotoSimilarity or use precomputed matrix
    # Alternative: use precomputed similarity matrix instead for speed

# Instead, better to compute similarity matrix using RDKit function:
from rdkit import DataStructs

# Create a similarity matrix for all molecules
similarity_matrix = np.zeros((len(df), len(df)))

for i in range(len(df)):
    for j in range(i, len(df)):
        sim = DataStructs.TanimotoSimilarity(df['rdkit_fp'].iloc[i], df['rdkit_fp'].iloc[j])
        similarity_matrix[i,j] = sim
        similarity_matrix[j,i] = sim

# Convert similarity to distance
distance_matrix = 1 - similarity_matrix

# Convert to condensed distance matrix for linkage
condensed_dist_matrix = squareform(distance_matrix)

# Perform hierarchical clustering
linked = linkage(condensed_dist_matrix, method='ward')

# Now assign clusters
threshold = 0.7
cluster_labels = fcluster(linked, threshold, criterion='distance')

df['cluster'] = cluster_labels

print(df['cluster'].value_counts())
# Out:
# cluster
# 42     11
# 135     8
# 2       8
# 143     8
# 124     7
#        ..
# 40      1
# 100     1
# 88      1
# 110     1
# 69      1
# Name: count, Length: 143, dtype: int64

# %%
# Get cluster counts sorted descending
cluster_counts = df['cluster'].value_counts().head(5)

print("Top 5 largest clusters and their sizes:")
print(cluster_counts)

# For each cluster in top 5, print molecule info
for cluster_id in cluster_counts.index:
    print(f"\nCluster {cluster_id} with {cluster_counts[cluster_id]} molecules:")
    cluster_mols = df[df['cluster'] == cluster_id][['ID', 'Smiles', 'cluster']]
    print(cluster_mols)
# Out:
# Top 5 largest clusters and their sizes:
# cluster
# 42     11
# 135     8
# 2       8
# 143     8
# 124     7
# Name: count, dtype: int64
#
# Cluster 42 with 11 molecules:
#             ID                                             Smiles  cluster
# 28   STK147525  OC(=O)CC(C(=O)Nc1c(=O)n(n(c1C)C)c1ccccc1)NCc1c...       42
# 60   STK064169     O=C(Nc1c(C)n(n(c1=O)c1ccccc1)C)CCSc1ccc(cc1)Cl       42
# 75   STK358393     O=C(Nc1c(C)n(n(c1=O)c1ccccc1)C)CSCc1ccc(cc1)Br       42
# 114  STK329855  C=CCc1ccc(c(c1)OC)OCC(=O)Nc1c(C)n(n(c1=O)c1ccc...       42
# 122  STK215290           O=C(Nc1c(C)n(n(c1=O)c1ccccc1)C)COCC(=O)O       42
# 155  STK001436  O=C(Nc1c(C)n(n(c1=O)c1ccccc1)C)CSc1nc2c([nH]1)...       42
# 179  STK282985  O=C(Nc1c(C)n(n(c1=O)c1ccccc1)C)Cn1nnnc1c1ccc(c...       42
# 252  STK330342      O=C(Nc1c(=O)n(n(c1C)C)c1ccccc1)Cc1c(F)cccc1Cl       42
# 277  STK226330  O=C(Nc1c(=O)n(n(c1C)C)c1ccccc1)CSc1nnc(o1)c1cc...       42
# ...

# %%
from rdkit import Chem
from rdkit.Chem import Draw

cluster_42_smiles = df[df['cluster'] == 42]['Smiles'].tolist()
cluster_42_mols = [Chem.MolFromSmiles(s) for s in cluster_42_smiles]

img = Draw.MolsToImage(cluster_42_mols[0])
img.show()
# Out:
# ------------------------------------------------
# ImportError    Traceback (most recent call last)
# Cell In[78], line 2
#       1 from rdkit import Chem
# ----> 2 from rdkit.Chem import Draw
#       4 cluster_42_smiles = df[df['cluster'] == 42]['Smiles'].tolist()
#       5 cluster_42_mols = [Chem.MolFromSmiles(s) for s in cluster_42_smiles]
#
# File ~\anaconda3\envs\cheminfo\Lib\site-packages\rdkit\Chem\Draw\__init__.py:21
#      19 from rdkit import rdBase
#      20 from rdkit.Chem import rdDepictor
# ---> 21 from rdkit.Chem.Draw import rdMolDraw2D
#      22 from rdkit.Chem.Draw.rdMolDraw2D import *
#      25 def _sip_available():
#
# ImportError: DLL load failed while importing rdMolDraw2D: The operation completed successfully.
